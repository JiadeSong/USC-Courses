# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pandas_datareader
import yfinance as yf

# %%
dfnames = pd.read_csv('constituents.csv')
dfnames[:5]
# Out:
#   Symbol                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology

# %%
dfprices = pd.read_csv('prices.csv')
dfprices[:5]
# Out:
#          Date         MMM        AOS        ABT       ABBV         ACN  \
# 0  2019-01-02  181.270157  42.208401  67.791504  80.913643  137.682632
# 1  2019-01-03  174.444626  41.188873  64.592140  78.247650  132.981903
# 2  2019-01-04  181.621399  42.839535  66.435669  80.768547  138.152725
# 3  2019-01-07  181.203720  43.606602  67.430595  81.947380  138.632599
# 4  2019-01-08  181.963150  44.674679  66.621002  82.328247  142.138565
#
#         ATVI         AYI        ADBE         AAP  ...        WLTW        WYNN  \
# 0  46.350380  114.464066  224.570007  156.691010  ...  147.045517  100.250526
# 1  44.704514  110.709183  215.699997  161.582657  ...  143.960770   99.280663
# 2  46.488358  115.894493  226.190002  157.574066  ...  147.851089  103.284927
# 3  47.799141  117.622940  229.259995  159.885956  ...  148.941528  105.119019
# 4  49.247898  119.738770  232.679993  158.774658  ...  149.894470  108.412689
#
# ...

# %%
dfnames[dfnames['Symbol'].str.startswith('GOOG')]
# Out:
#    Symbol                  Name                  Sector
# 25  GOOGL  Alphabet Inc Class A  Information Technology
# 26   GOOG  Alphabet Inc Class C  Information Technology

# %%
dfnames.drop(dfnames[dfnames.Symbol=='GOOG'].index,axis=0,inplace=True)
dfnames.drop(dfnames[dfnames.Symbol=='DISCK'].index,axis=0,inplace=True)

# %%
dfprices.drop(['GOOG'],axis=1,inplace=True)
dfprices.drop(['DISCK'],axis=1,inplace=True)

# %% [markdown]
# ## 1. (a), (b)

# %%
net_returns = dfprices.iloc[:,1:461] / dfprices.iloc[:,1:461].shift(1) - 1
net_returns
# Out:
#           MMM       AOS       ABT      ABBV       ACN      ATVI       AYI  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   -0.037654 -0.024155 -0.047194 -0.032949 -0.034142 -0.035509 -0.032804
# 2    0.041141  0.040075  0.028541  0.032217  0.038884  0.039903  0.046837
# 3   -0.002300  0.017906  0.014976  0.014595  0.003474  0.028196  0.014914
# 4    0.004191  0.024493 -0.012006  0.004648  0.025290  0.030309  0.017988
# ..        ...       ...       ...       ...       ...       ...       ...
# 350  0.004321 -0.010778  0.011948 -0.009890  0.001085  0.008417  0.005575
# 351  0.038514  0.061819 -0.021756 -0.015092  0.013887 -0.042146  0.060981
# 352  0.039913  0.053089  0.014305 -0.008048  0.017974  0.002143  0.048471
# 353 -0.008410 -0.013133  0.014764  0.000556  0.008703  0.000998 -0.057788
# 354 -0.002423  0.019532  0.030619  0.029324 -0.000248  0.025064 -0.030497
#
#          ADBE       AAP       AMD  ...      WLTW      WYNN       XEL  \
# ...

# %%
corrs = abs(net_returns.corr())
corrs
# Out:
#            MMM       AOS       ABT      ABBV       ACN      ATVI       AYI  \
# MMM   1.000000  0.594449  0.576961  0.452514  0.635089  0.291471  0.588411
# AOS   0.594449  1.000000  0.453195  0.343838  0.514166  0.330122  0.524742
# ABT   0.576961  0.453195  1.000000  0.568671  0.696058  0.440851  0.462863
# ABBV  0.452514  0.343838  0.568671  1.000000  0.563359  0.387061  0.427824
# ACN   0.635089  0.514166  0.696058  0.563359  1.000000  0.438397  0.634482
# ...        ...       ...       ...       ...       ...       ...       ...
# XYL   0.694108  0.608648  0.622988  0.476572  0.718796  0.331620  0.659410
# YUM   0.515977  0.351790  0.533643  0.401950  0.665116  0.157692  0.537909
# ZBH   0.516901  0.376173  0.485332  0.424567  0.656766  0.167409  0.561865
# ZION  0.618936  0.609799  0.453002  0.399792  0.633461  0.212934  0.634437
# ZTS   0.531877  0.427140  0.705734  0.524452  0.704295  0.371696  0.537013
#
# ...

# %%
corrmatrix1 = corrs.values
np.fill_diagonal(corrmatrix1,0)
print(np.round(corrmatrix1,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-65e7ef54fab3> in <module>
# ----> 1 corrmatrix1 = corrs.values
#       2 np.fill_diagonal(corrmatrix1,0)
#       3 print(np.round(corrmatrix1,3))
#
# NameError: name 'corrs' is not defined

# %%
np.amax(corrmatrix1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac33e014104a> in <module>
# ----> 1 np.amax(corrmatrix1)
#
# NameError: name 'np' is not defined

# %%
np.where(corrmatrix1 == np.amax(corrmatrix1))
# Out:
# (array([416, 417]), array([417, 416]))

# %%
corrmatrix2 = corrs.values
np.fill_diagonal(corrmatrix2,1)
print(np.round(corrmatrix2,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-85541a511966> in <module>
# ----> 1 corrmatrix2 = corrs.values
#       2 np.fill_diagonal(corrmatrix2,1)
#       3 print(np.round(corrmatrix2,3))
#
# NameError: name 'corrs' is not defined

# %%
np.amin(corrmatrix2)
# Out:
# 5.541737792574135e-05

# %%
np.where(corrmatrix2 == np.amin(corrmatrix2))
# Out:
# (array([ 94, 371]), array([371,  94]))

# %%
print(dfnames.iloc[416,0],dfnames.iloc[417,0])
print(dfnames.iloc[416,1],dfnames.iloc[417,1])
# Out:
# UAA UA
# Under Armour Class A Under Armour Class C

# %%
print(dfnames.iloc[94,0],dfnames.iloc[371,0])
print(dfnames.iloc[94,1],dfnames.iloc[371,1])
# Out:
# CHD SCG
# Church & Dwight SCANA Corp

# %% [markdown]
# ## 2. (a)

# %%
sampleprices = dfprices.loc[:,samplestocks.Symbol]
sampleprices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1ea5cd3e2b47> in <module>
# ----> 1 sampleprices = dfprices.loc[:,samplestocks.Symbol]
#       2 sampleprices
#
# NameError: name 'dfprices' is not defined

# %%
net_returns1 = sampleprices/ sampleprices.shift(1) - 1
net_returns1
# Out:
#           BWA       ECL        PH        LB      INTC       TIF       SNA  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   -0.030174 -0.023323 -0.036904  0.005701 -0.055013 -0.027374 -0.013563
# 2    0.037570  0.036244  0.044808  0.047241  0.061362  0.035055  0.036505
# 3    0.026026  0.002932  0.003634  0.041862  0.004659  0.042729  0.012801
# 4    0.031431  0.012168  0.020872 -0.023208  0.006324  0.012456  0.012770
# ..        ...       ...       ...       ...       ...       ...       ...
# 350 -0.002007  0.000499  0.000900  0.043599  0.004518 -0.010209 -0.030029
# 351  0.056300  0.020399  0.076402  0.106101  0.001285  0.002399  0.063004
# 352  0.032360  0.013490  0.022602  0.031175  0.019570  0.017309 -0.005766
# 353 -0.013522  0.019580 -0.026512 -0.053488 -0.029264  0.002195 -0.018060
# 354  0.006890  0.005534  0.006431 -0.005528  0.019935  0.002425 -0.030355
#
#             K
# 0         NaN
# 1    0.001766
# 2    0.009870
# 3    0.004712
# ...

# %%
net_returns1.std()
# Out:
# BWA     0.027554
# ECL     0.023962
# PH      0.031607
# LB      0.049634
# INTC    0.028167
# TIF     0.024281
# SNA     0.025258
# K       0.018762
# dtype: float64

# %% [markdown]
# ## 2. (b)

# %%
net_returns2 = sampleprices.iloc[354,:] / sampleprices.iloc[0,:] - 1
net_returns2
# Out:
# BWA    -0.058045
# ECL     0.485213
# PH      0.232712
# LB     -0.339687
# INTC    0.384531
# TIF     0.609936
# SNA    -0.084750
# K       0.220404
# dtype: float64

# %%
net_returns2.max()
# Out:
# 0.609935589815354
